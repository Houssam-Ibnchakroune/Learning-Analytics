# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
test_web= pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', sep='|')

# %%
test_web.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
assesmnet=pd.read_csv("../data/raw/open+university+learning+analytics+dataset/assessments.csv")
courses = pd.read_csv("../data/raw/open+university+learning+analytics+dataset/courses.csv")
studentAssessement = pd.read_csv("../data/raw/open+university+learning+analytics+dataset/studentAssessment.csv")
studentInfo = pd.read_csv("../data/raw/open+university+learning+analytics+dataset/studentInfo.csv")
studentRegistration = pd.read_csv("../data/raw/open+university+learning+analytics+dataset/studentRegistration.csv")
studentVle = pd.read_csv("../data/raw/open+university+learning+analytics+dataset/studentVle.csv")
vle = pd.read_csv("../data/raw/open+university+learning+analytics+dataset/vle.csv")

# %%
courses.head()
# Out:
#   code_module code_presentation  module_presentation_length
# 0         AAA             2013J                         268
# 1         AAA             2014J                         269
# 2         BBB             2013J                         268
# 3         BBB             2014J                         262
# 4         BBB             2013B                         240

# %%
studentInfo.shape
# Out:
# (32593, 12)

# %%
studentInfo.info()
studentInfo.nunique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32593 entries, 0 to 32592
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   code_module           32593 non-null  object
#  1   code_presentation     32593 non-null  object
#  2   id_student            32593 non-null  int64
#  3   gender                32593 non-null  object
#  4   region                32593 non-null  object
#  5   highest_education     32593 non-null  object
#  6   imd_band              32593 non-null  object
#  7   age_band              32593 non-null  object
#  8   num_of_prev_attempts  32593 non-null  int64
#  9   studied_credits       32593 non-null  int64
#  10  disability            32593 non-null  object
#  11  final_result          32593 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 3.0+ MB
# code_module                 7
# code_presentation           4
# id_student              28785
# ...

# %%
print(studentInfo['final_result'].value_counts())
sns.countplot(data=studentInfo, x='final_result')
# Out:
# final_result
# Pass           12361
# Withdrawn      10156
# Fail            7052
# Distinction     3024
# Name: count, dtype: int64
# <Axes: xlabel='final_result', ylabel='count'>

# %%
print(studentInfo.isnull().sum())
print(studentAssessement.isnull().sum())
# Out:
# code_module             0
# code_presentation       0
# id_student              0
# gender                  0
# region                  0
# highest_education       0
# imd_band                0
# age_band                0
# num_of_prev_attempts    0
# studied_credits         0
# disability              0
# final_result            0
# dtype: int64
# id_assessment     0
# id_student        0
# date_submitted    0
# is_banked         0
# score             0
# dtype: int64

# %%
print(studentInfo.describe())
print("="*70)
print(studentInfo['gender'].value_counts())
print("="*70)
print(studentInfo['highest_education'].value_counts())
# Out:
#          id_student  num_of_prev_attempts  studied_credits
# count  3.259300e+04          32593.000000     32593.000000
# mean   7.066877e+05              0.163225        79.758691
# std    5.491673e+05              0.479758        41.071900
# min    3.733000e+03              0.000000        30.000000
# 25%    5.085730e+05              0.000000        60.000000
# 50%    5.903100e+05              0.000000        60.000000
# 75%    6.444530e+05              0.000000       120.000000
# max    2.716795e+06              6.000000       655.000000
# ...
# gender
# M    17875
# F    14718
# Name: count, dtype: int64
# ...
# highest_education
# A Level or Equivalent          14045
# Lower Than A Level             13158
# HE Qualification                4730
# No Formal quals                  347
# Post Graduate Qualification      313
# Name: count, dtype: int64

# %%
# Échec vs nombre de tentatives précédentes
print(studentInfo.groupby('num_of_prev_attempts')['final_result'].value_counts())
sns.countplot(data=studentInfo, x='num_of_prev_attempts', hue='final_result')
# Out:
# num_of_prev_attempts  final_result
# 0                     Pass            11148
#                       Withdrawn        8685
#                       Fail             5731
#                       Distinction      2857
# 1                     Withdrawn        1150
#                       Fail             1009
#                       Pass              997
#                       Distinction       143
# 2                     Withdrawn         247
#                       Fail              236
#                       Pass              170
#                       Distinction        22
# 3                     Fail               57
#                       Withdrawn          53
#                       Pass               31
#                       Distinction         1
# 4                     Withdrawn          14
#                       Pass               13
#                       Fail               12
# 5                     Fail                6
# ...
